# %% [markdown]
# # Multiple Regression to predict miles per gallon on cars for a rental car company.

# %%
import pandas as pd
from IPython.display import display, HTML

# read data from mtcars.csv data set.
cars_df = pd.read_csv("https://s3-us-west-2.amazonaws.com/data-analytics.zybooks.com/mtcars.csv")

print("Cars data frame (showing only the first five observations)\n")
display(HTML(cars_df.head().to_html()))
# Out:
# Cars data frame (showing only the first five observations)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>mpg</th>
#       <th>cyl</th>
#       <th>disp</th>
#       <th>hp</th>
#       <th>drat</th>
#       <th>wt</th>
#       <th>qsec</th>
#       <th>vs</th>
#       <th>am</th>
#       <th>gear</th>
#       <th>carb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Mazda RX4</td>
#       <td>21.0</td>
#       <td>6</td>
#       <td>160.0</td>
#       <td>110</td>
#       <td>3.90</td>
#       <td>2.620</td>
#       <td>16.46</td>
#       <td>0</td>
#       <td>1</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mazda RX4 Wag</td>
#       <td>21.0</td>
#       <td>6</td>
#       <td>160.0</td>
#       <td>110</td>
#       <td>3.90</td>
#       <td>2.875</td>
#       <td>17.02</td>
#       <td>0</td>
# ...

# %%
import matplotlib.pyplot as plt

# create scatterplot of variables mpg against wt.
plt.plot(cars_df["wt"], cars_df["mpg"], 'o', color='red')

plt.title('MPG against Weight')
plt.xlabel('Weight (1000s lbs)')
plt.ylabel('MPG')

plt.show()

# %%
import matplotlib.pyplot as plt

# create scatterplot of variables mpg against hp.
plt.plot(cars_df["hp"], cars_df["mpg"], 'o', color='blue')

# set a title for the plot, x-axis, and y-axis.
plt.title('MPG against Horsepower')
plt.xlabel('Horsepower')
plt.ylabel('MPG')

# show the plot.
plt.show()

# %% [markdown]
# <br><br>

# %% [markdown]
# # Correlation Matrix is given below for all variables

# %%
corr = cars_df.corr()
corr.style.set_precision(3).background_gradient(cmap="RdBu", vmin = -1, vmax = 1)
# Out:
# <style  type="text/css" >
# #T_296b1b06_c7f8_11ec_873c_acde48001122row0_col0,#T_296b1b06_c7f8_11ec_873c_acde48001122row1_col1,#T_296b1b06_c7f8_11ec_873c_acde48001122row2_col2,#T_296b1b06_c7f8_11ec_873c_acde48001122row3_col3,#T_296b1b06_c7f8_11ec_873c_acde48001122row4_col4,#T_296b1b06_c7f8_11ec_873c_acde48001122row5_col5,#T_296b1b06_c7f8_11ec_873c_acde48001122row6_col6,#T_296b1b06_c7f8_11ec_873c_acde48001122row7_col7,#T_296b1b06_c7f8_11ec_873c_acde48001122row8_col8,#T_296b1b06_c7f8_11ec_873c_acde48001122row9_col9,#T_296b1b06_c7f8_11ec_873c_acde48001122row10_col10{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_296b1b06_c7f8_11ec_873c_acde48001122row0_col1,#T_296b1b06_c7f8_11ec_873c_acde48001122row1_col0{
#             background-color:  #9c1127;
#             color:  #f1f1f1;
#         }#T_296b1b06_c7f8_11ec_873c_acde48001122row0_col2,#T_296b1b06_c7f8_11ec_873c_acde48001122row2_col0{
#             background-color:  #9f1228;
# ...

# %% [markdown]
# <br><br>

# %%
_ = cars_df.hist(figsize=(12,12), grid = False)

# %% [markdown]
# <br><br><br>

# %% [markdown]
# # Multiple regression model to predict miles per gallon using weight and horsepower

# %%
from statsmodels.formula.api import ols

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     69.21
# Date:                Fri, 29 Apr 2022   Prob (F-statistic):           9.11e-12
# Time:                        16:11:21   Log-Likelihood:                -74.326
# No. Observations:                  32   AIC:                             154.7
# Df Residuals:                      29   BIC:                             159.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.2273      1.599     23.285      0.000      33.957      40.497
# ...

# %% [markdown]
# # Multiple Regression Equation
#
# The multiple regression model is given by: $Y = 40.497-2.584wt-0.013hp$
# <br>
# With this equation, we can predict the miles per gallon of a car given the weight and horse power.
